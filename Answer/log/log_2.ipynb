# %%
# Time: 2024-05-19 08:51:17.784044 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst= str(input_data)print(st[::-1])
# Out:
# olleh

# %%
# Time: 2024-05-19 08:51:18.171960 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst= str(input_data)print(st[::-1])
# Out:
# nohtyp

# %%
# Time: 2024-05-19 08:51:18.553260 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst= str(input_data)print(st[::-1])
# Out:
# olleh nohtyp

# %%
# Time: 2024-05-19 10:05:11.073236 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysfor i in str(input_data):    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
# Time: 2024-05-19 10:05:11.490383 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysfor i in str(input_data):    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
# Time: 2024-05-19 10:05:11.798292 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysfor i in str(input_data):    print(i)
# Out:
# p
# y
# t
# h
# o
# n
#
# h
# e
# l
# l
# o

# %%
# Time: 2024-05-19 10:25:38.245858 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh

# %%
# Time: 2024-05-19 10:25:38.414890 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# nohtyp

# %%
# Time: 2024-05-19 10:25:38.685814 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh nohtyp

# %%
# Time: 2024-05-19 10:40:04.832709 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh

# %%
# Time: 2024-05-19 10:40:05.299375 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# nohtyp

# %%
# Time: 2024-05-19 10:40:05.585170 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh nohtyp

# %%
# Time: 2024-05-19 23:03:52.587318 for username: TESTNAME

# %%
# Time: 2024-05-19 23:03:52.727501 for username: TESTNAME

# %%
# Time: 2024-05-19 23:03:52.842058 for username: TESTNAME

# %%
# Time: 2024-05-19 23:25:29.576757 for username: TESTNAME

# %%
# Time: 2024-05-19 23:25:29.767152 for username: TESTNAME

# %%
# Time: 2024-05-19 23:25:29.901649 for username: TESTNAME

# %%
# Time: 2024-05-19 23:26:08.523979 for username: TESTNAME

# %%
# Time: 2024-05-19 23:26:08.650388 for username: TESTNAME

# %%
# Time: 2024-05-19 23:26:09.139748 for username: TESTNAME

# %%
# Time: 2024-05-19 23:26:18.308502 for username: TESTNAME

# %%
# Time: 2024-05-19 23:26:18.773938 for username: TESTNAME

# %%
# Time: 2024-05-19 23:26:18.980604 for username: TESTNAME

# %%
# Time: 2024-05-19 23:27:13.835733 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh

# %%
# Time: 2024-05-19 23:27:14.033910 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# nohtyp

# %%
# Time: 2024-05-19 23:27:14.282959 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh nohtyp

# %%
# Time: 2024-05-19 23:56:26.066432 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])#code edited
# Out:
# olleh

# %%
# Time: 2024-05-19 23:56:26.211191 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])#code edited
# Out:
# nohtyp

# %%
# Time: 2024-05-19 23:56:26.324438 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])#code edited
# Out:
# olleh nohtyp

# %%
# Time: 2024-05-20 00:04:15.084504 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])#code edited
# Out:
# olleh

# %%
# Time: 2024-05-20 00:04:15.262887 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])#code edited
# Out:
# nohtyp

# %%
# Time: 2024-05-20 00:04:15.556414 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])#code edited
# Out:
# olleh nohtyp
