# %%
# Time: 2024-05-19 08:51:17.784044 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst= str(input_data)print(st[::-1])
# Out:
# olleh

# %%
# Time: 2024-05-19 08:51:18.171960 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst= str(input_data)print(st[::-1])
# Out:
# nohtyp

# %%
# Time: 2024-05-19 08:51:18.553260 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst= str(input_data)print(st[::-1])
# Out:
# olleh nohtyp

# %%
# Time: 2024-05-19 10:05:11.073236 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysfor i in str(input_data):    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
# Time: 2024-05-19 10:05:11.490383 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysfor i in str(input_data):    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
# Time: 2024-05-19 10:05:11.798292 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysfor i in str(input_data):    print(i)
# Out:
# p
# y
# t
# h
# o
# n
#
# h
# e
# l
# l
# o

# %%
# Time: 2024-05-19 10:25:38.245858 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh

# %%
# Time: 2024-05-19 10:25:38.414890 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# nohtyp

# %%
# Time: 2024-05-19 10:25:38.685814 for username: TESTNAME#Dont edit this line of codeimport sysinput_data = eval(sys.argv[1])del sysst = str(input_data)print(st[::-1])
# Out:
# olleh nohtyp
